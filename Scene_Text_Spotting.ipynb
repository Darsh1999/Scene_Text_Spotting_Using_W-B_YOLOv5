# %%
# %%capture
# !git clone https://github.com/ultralytics/yolov5.git
# !curl -L "https://app.roboflow.com/ds/UUgiVi2WCf?key=ZRYwFlbGvs" > roboflow.zip; unzip -o roboflow.zip; rm roboflow.zip
# %cd /content/yolov5
# !pip install -r requirements.txt
# !pip install "wandb==0.12.10"

# %%
# !python train.py \
  --data ../data.yaml \
  --epochs 100 \
  --project yolo-wandb-demo1 \
  --upload_dataset \
  --bbox_interval 1 \
  --save-period 1
# Out:
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout) 2
# wandb: You chose 'Use an existing W&B account'
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# ...

# %%
/content/train/labels/img_10_jpg.rf.69939267d1f6f3f775c4d87cad0149f2.txt
